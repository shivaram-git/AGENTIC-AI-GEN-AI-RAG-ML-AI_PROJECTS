# %%
# Framework : set of rules,package
# Package :  Collection of modules
# Module : collection of functions
# Function :
#          inbuilt function == print(),id(),type()
#           user define function

# Machine Learning Framework : sklearn,xgboost,lgbm
# AI(NLP Framework)          :  NLTK, spacy
# deep Learining Framework   : Tenserflow, keras
# Generative framerwork      :  Langchain, Langgraph, langsmith
# Agentic AI Framework       : Crew AI, phi, agno , autogen, smolagent


# Framework == package + module + function + set of rules

# %%
25
# Out:
# 25

# %%
import math

math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(3.5)
# Out:
# 3

# %%
math.ceil(3.5)
# Out:
# 4

# %%
math.floor(4.9)
# Out:
# 4

# %%
math.ceil(4.9)
# Out:
# 5

# %%
math.ceil(4.1)
# Out:
# 5

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.pow(5,2)
# Out:
# 25.0

# %%
import math as m

m.ceil(8.4)
# Out:
# 9

# %%
m.floor(3.6)
# Out:
# 3

# %%
print(m.floor(3.4))
print(m.ceil(3.4))
print(m.sqrt(25))
print(m.pow(2,2))
# Out:
# 3
# 4
# 5.0
# 4.0

# %%
from math import pow,floor,ceil,sqrt  # it can understand 4 functions only

print(pow(4,3))
print(floor(3.5))
print(ceil(4.2))
print(sqrt(64))
# Out:
# 64.0
# 3
# 5
# 8.0

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  math
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
# ...

# %%
from math import *  # means  work all math inbuilt functions

print(pow(3,4))
print(floor(3.5))
print(ceil(4.2))
print(sqrt(64))
# Out:
# 81.0
# 3
# 5
# 8.0

# %% [markdown]
# ## input() function

# %%
 x = input()
 y = input()

 z = x + y
 print(z)
# Out:
#  10
#  20
# 1020

# %%
from math import *

a = int(input())
b = int(input())
c = a + b
c
# Out:
#  5
#  4
# 9

# %%
a = eval(input('express a values'))
a
# Out:
# express a values 2+3+5-2
# 8

# %%
adhaar = input('enter')[8:]
print('********',adhaar)
# Out:
# enter 1234567891011
# ******** 91011

# %%
x = input("usrname")
y = input("password")

print(x)
print(y)
# Out:
# usrname shiva
# password shiva@password
# shiva
# shiva@password
