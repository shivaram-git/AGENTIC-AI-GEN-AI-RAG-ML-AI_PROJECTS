# %% [markdown]
# ### List
# 1) List is an odered sequence of items
# 2)  We can hav different data types under a list. E.g we can have integer, float and string items in
# a same list.

# %% [markdown]
# ### List Creation

# %%
list1 = [] # Empty list

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10,20,30] # list of integers

# %%
list3 = [10.5,20.4,30.3] # List of float

# %%
list4 = ['one','two','three']  # list of strings

# %%
list5 = ['shiva',20,[46,'ram'],[80,90]] # Nested list

# %%
list6 = ['ram',3.8,True,10,1+2j]  # list of mixed data types

# %%
list7 = ['Shiva',20,[10,2,45],[150],{"Shiva","ram"}]

# %%
len(list6)
# Out:
# 5

# %% [markdown]
# ### List Indexing

# %%
list2[0] # Retrive first element of list
# Out:
# 10

# %%
list4[2] # Retrive third element of list
# Out:
# 'three'

# %%
list7[2][1] # Retrive from nested list
# Out:
# 2

# %%
list2[::-1]  # Reverse list
# Out:
# [30, 20, 10]

# %%
list3[-1] #last  item list
# Out:
# 30.3

# %% [markdown]
# ### list slicing

# %%
list7[:3]
# Out:
# ['Shiva', 20, [10, 2, 45]]

# %%
list7[1:4]
# Out:
# [20, [10, 2, 45], [150]]

# %%
list7[-2:] # slicing last two items
# Out:
# [[150], {'Shiva', 'ram'}]

# %%
list4[-2:]
# Out:
# ['two', 'three']

# %%
list4[:]
# Out:
# ['one', 'two', 'three']

# %% [markdown]
# ### Add, Removing & Change Items

# %%
list4
# Out:
# ['one', 'two', 'three']

# %%
list4.append('four')  # add item to the end of a list

# %%
list4
# Out:
# ['one', 'two', 'three', 'four', 'four']

# %%
list4.insert(0,'zero') # add item at a index
list4
# Out:
# ['zero', 'zero', 'one', 'two', 'three', 'four', 'four']

# %%
list4.insert(4,'Three')
list4
# Out:
# ['zero', 'zero', 'one', 'two', 'Three', 'three', 'four', 'four']

# %%
list4.remove('Three') # remove item from list

# %%
list4
# Out:
# ['zero', 'zero', 'one', 'two', 'three', 'four', 'four']

# %%
list4.pop() # remove last item 
list4
# Out:
# ['zero', 'zero', 'one', 'two', 'three', 'four']

# %%
list4.pop(1)
list4
# Out:
# ['zero', 'one', 'two', 'three', 'four']

# %%
del list4[4]     # Remove item at index location 4
list4
# Out:
# ['zero', 'one', 'two', 'three']

# %%
list4[0] = 0
list4[1] = 1            #Change value of the string
list4[2] = 2
list4[3] = 3

list4
# Out:
# [0, 1, 2, 3]

# %%
list4.clear()

# %%
list4
# Out:
# []

# %%
del list4

# %%
list4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 list4
#
# NameError: name 'list4' is not defined

# %% [markdown]
# ### copy list

# %%
list2
# Out:
# [10, 20, 30]

# %%
list8 = list2 # Create a new reference "list8"

# %%
id(list8) , id(list2) # The address of both mylist & mylist1 will be the same
# Out:
# (1720519412416, 1720519412416)

# %%
list9 = list2.copy() # Create a copy of the list

# %%
id(list9) , id(list2)
# Out:
# (1720521788416, 1720519412416)

# %%
list8[0] = 55  # mylist1 will be also impacted as it is pointing to the same list
print(list8,list2)
# Out:
# [55, 20, 30] [55, 20, 30]

# %%
list9[0] = 80  # Copy of list won't be impacted due to changes made on the original lis
print(list9,list2)
# Out:
# [80, 20, 30] [55, 20, 30]

# %%
###n join lists

# %%
list1 = ['one', 'two', 'three', 'four']
list2 = ['five', 'six', 'seven', 'eight']

# %%
list3 = list2+list1
list3
# Out:
# ['five', 'six', 'seven', 'eight', 'one', 'two', 'three', 'four']

# %%
list1.extend(list2) #Append list2 with list1
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']
