# %% [markdown]
# # Data Types

# %%
i = 10
print(i)
# Out:
# 10

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140705997694152

# %%
age = 23
print(age)
# Out:
# 23

# %%
print(type(age))
print(id(age))
# Out:
# <class 'int'>
# 140705997694568

# %% [markdown]
# # Float

# %%
f = 10.5
print(f)
# Out:
# 10.5

# %%
type(f)
# Out:
# float

# %%
id(f)
# Out:
# 1314281450128

# %%
print(i)
print(f)
# Out:
# 10
# 10.5

# %% [markdown]
# # Bool

# %%
b = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 b = true
#
# NameError: name 'true' is not defined

# %%
b = True
print(b)
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1 = False
print(b1)
# Out:
# False

# %%
p = 20
q = 20

# %%
p,q = 20,20

print(id(p))
print(id(q))
# Out:
# 140705997694472
# 140705997694472

# %%
p = p + 20
print(p)
# Out:
# 40

# %%
print(id(p))
print(id(q))
# Out:
# 140705997695112
# 140705997694472

# %%
print(b)
print(b1)
# Out:
# True
# False

# %%
print(True + False)
print(False + True)
# Out:
# 1
# 1

# %%
print(True * False)
print(False * True)
# Out:
# 0
# 0

# %%
print(False / True)
print(False // True)
# Out:
# 0.0
# 0

# %%
print(True/False)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(True/False)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # Complex

# %%
c = 10+20j
print(c)
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c1 = 100+200j
print(c1)
# Out:
# (100+200j)

# %%
c2 = c+c1
print(c2)
# Out:
# (110+220j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c1.real
# Out:
# 100.0

# %%
c1.imag
# Out:
# 200.0

# %%
print(c)
print(c1)
print(c2)
# Out:
# (10+20j)
# (100+200j)
# (110+220j)

# %% [markdown]
# # STRINGS

# %%
s = "shivaram"
print(s)
print(type(s))
# Out:
# shivaram
# <class 'str'>

# %%
s = "shivaram"
print(s[5])
print(s[2])
# Out:
# r
# i

# %%
s1 = "Apple"
print(s1[1:3])
print(s1[2:])
# Out:
# pp
# ple

# %%
s1 = "Data Science"
print(s1[-6:])
# Out:
# cience

# %%
print(s1[:-5])
print(s1[-18:-3])
# Out:
# Data Sc
# Data Scie

# %%
s2 = "welcome"
print(s2[1:6:2])
# Out:
# ecm

# %%
int(True)  # boolean to int possible
# Out:
# 1

# %%
int(1+2j)  # Complex to integer in type casting is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 int(1+2j)  # Complex to integer in type casting is not possible
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
print(int('10'))   # Number string to integer to in type Casting is Possible where text String is not possible
int('ten1')
# Out:
# 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 print(int('10'))   # Number string to integer to in type Casting is Possible where text String is not possible
# ----> 2 int('ten1')
#
# ValueError: invalid literal for int() with base 10: 'ten1'

# %% [markdown]
# # Other Data type to Float

# %%
print(float(11))  # Integer to Float
print(float(True))  # Bool to Float
print(float(False))
# Out:
# 11.0
# 1.0
# 0.0

# %%
print(float(1+2j))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(float(1+2j))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
print(float('10'))
# Out:
# 10.0

# %%
import keyword as kw

print(kw.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Other Dattype to Boolean
#    # Every data type to Boolean is possible for type casting

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool('shiva')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
# All other Data type to Complex

# %%
print(complex(2))
print(complex(5.5))
# Out:
# (2+0j)
# (5.5+0j)

# %%
print(complex(10,8))
print(complex(3,4,5))
# Out:
# (10+8j)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 print(complex(10,8))
# ----> 2 print(complex(3,4,5))
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3,48.5)
# Out:
# (2.3+48.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
print(complex('10'))
# Out:
# (10+0j)

# %%
print(complex('12','5'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print(complex('12','5'))
#
# TypeError: complex() can't take second arg if first is a string

# %%
print(complex(10,'5'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(complex(10,'5'))
#
# TypeError: complex() second arg can't be a string

# %%
str(10)
# Out:
# '10'

# %%
str(15.8)
# Out:
# '15.8'

# %%
str(False)
# Out:
# 'False'

# %%
str(10+5j)
# Out:
# '(10+5j)'
